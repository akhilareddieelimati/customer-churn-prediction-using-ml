# %%
import pandas as pd

# %%
data=pd.read_csv('Dataset/telecom_customer_churn.csv')
data.shape
# Out:
# (7043, 38)

# %%
data.drop(columns=['Customer ID','City','Zip Code','Offer','Unlimited Data','Churn Category','Churn Reason','Premium Tech Support'], inplace=True)

# %%
data.shape
# Out:
# (7043, 30)

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (4835, 30)

# %%
data['Customer Status'].unique()
# Out:
# array(['Stayed', 'Churned', 'Joined'], dtype=object)

# %%
data['Gender']=data['Gender'].map({'Female':1,'Male':0})
data['Married']=data['Married'].map({'Yes':1,'No':0})
data['Phone Service']=data['Phone Service'].map({'Yes':1,'No':0})

data['Multiple Lines']=data['Multiple Lines'].map({'Yes':1,'No':0})
data['Internet Service']=data['Internet Service'].map({'Yes':1,'No':0})
data['Internet Type']=data['Internet Type'].map({'Cable':2,'Fiber Optic':0,'DSL':1})

data['Online Security']=data['Online Security'].map({'Yes':1,'No':0})
data['Online Backup']=data['Online Backup'].map({'Yes':1,'No':0})
data['Device Protection Plan']=data['Device Protection Plan'].map({'Yes':1,'No':0})
#data['Premium Tech Support']=data['Premium Tech Support'].map({'Fiber Optic':0,'DSL':1,'Cable':2})


data['Streaming TV']=data['Streaming TV'].map({'Yes':1,'No':0})
data['Streaming Movies']=data['Streaming Movies'].map({'Yes':1,'No':0})
data['Streaming Music']=data['Streaming Music'].map({'Yes':1,'No':0})

data['Contract']=data['Contract'].map({'Month-to-Month':0,'One Year':1,'Two Year':2})
data['Paperless Billing']=data['Paperless Billing'].map({'Yes':1,'No':0})

data['Payment Method']=data['Payment Method'].map({'Bank Withdrawal':0,'Credit Card':1,'Mailed Check':2})
data['Customer Status']=data['Customer Status'].map({'Stayed':0,'Churned':1,'Joined':2})

# %%
data['Gender'].isnull().sum()
# Out:
# 0

# %%
data['Married'].isnull().sum()
# Out:
# 0

# %%
data['Phone Service'].isnull().sum()
# Out:
# 0

# %%
data['Multiple Lines'].isnull().sum()
# Out:
# 0

# %%
data['Internet Service'].isnull().sum()
# Out:
# 0

# %%
data['Internet Type'].isnull().sum()
# Out:
# 0

# %%
data['Online Security'].isnull().sum()
# Out:
# 0

# %%
data['Online Backup'].isnull().sum()
# Out:
# 0

# %%
data['Device Protection Plan'].isnull().sum()
# Out:
# 0

# %%
#data['Premium Tech Support'].isnull().sum()

# %%
data['Streaming TV'].isnull().sum()
# Out:
# 0

# %%
data['Streaming Movies'].isnull().sum()
# Out:
# 0

# %%
data['Streaming Music'].isnull().sum()
# Out:
# 0

# %%
data['Contract'].isnull().sum()
# Out:
# 0

# %%
data['Paperless Billing'].isnull().sum()
# Out:
# 0

# %%
data['Payment Method'].isnull().sum()
# Out:
# 0

# %%
data['Customer Status'].isnull().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    Gender  Age  Married  Number of Dependents   Latitude   Longitude  \
# 0       1   37        1                     0  34.827662 -118.999073
# 1       0   46        0                     0  34.162515 -118.203869
# 2       0   50        0                     0  33.645672 -117.922613
# 3       0   78        1                     0  38.014457 -122.115432
# 4       1   75        1                     0  34.227846 -119.079903
#
#    Number of Referrals  Tenure in Months  Phone Service  \
# 0                    2                 9              1
# 1                    0                 9              1
# 2                    0                 4              1
# 3                    1                13              1
# 4                    3                 3              1
#
#    Avg Monthly Long Distance Charges  ...  Contract  Paperless Billing  \
# 0                              42.39  ...         1                  1
# 1                              10.69  ...         0                  0
# 2                              33.65  ...         0                  1
# 3                              27.82  ...         0                  1
# 4                               7.38  ...         0                  1
#
#    Payment Method  Monthly Charge  Total Charges  Total Refunds  \
# 0               1            65.6         593.30           0.00
# 1               1            -4.0         542.40          38.33
# 2               0            73.9         280.85           0.00
# 3               0            98.0        1237.85           0.00
# 4               1            83.9         267.40           0.00
#
#    Total Extra Data Charges  Total Long Distance Charges  Total Revenue  \
# 0                         0                       381.51         974.81
# 1                        10                        96.21         610.28
# 2                         0                       134.60         415.45
# 3                         0                       361.66        1599.51
# 4                         0                        22.14         289.54
#
#    Customer Status
# 0                0
# 1                0
# 2                1
# 3                1
# 4                1
#
# [5 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
data.shape
# Out:
# (4835, 30)

# %%
X = data.iloc[:, 0:29]
y = data.iloc[:, 29:30]

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
model=RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# C:\Users\gkvte\AppData\Local\Temp\ipykernel_2308\4186410530.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train,y_train)
# RandomForestClassifier()

# %%
svm_model=svm.SVC()

# %%
svm_model.fit(X_train,y_train)
# Out:
# C:\Users\gkvte\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()
